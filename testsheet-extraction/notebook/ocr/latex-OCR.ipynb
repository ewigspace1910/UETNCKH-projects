# %%
# !pip install pix2tex

# %%
# !pip install gdown
# !gdown -O data.zip  --id 1qNpaKvCyotOj43Z4FrQhamMetzSiDPQQ
# !gdown -O testds.zip --id 1aRry9bdEPSO83JQwvZ_By5Xyp2FQBVyx
# !gdown -O cropped.zip --id 12uYi8cK4yqEfd7_VWQgjek5S30otOiek
# !unzip data.zip
# !unzip testds.zip
# !unzip cropped.zip

# %%
source = "/content/content/cropped_img/44-1.jpg"

# %%
from PIL import Image
from pix2tex.cli import LatexOCR

img = Image.open(source)
model = LatexOCR()
result = model(img)

# %%
result
# Out:
# '\\begin{array}{r l}{{\\stackrel{\\mathrm{leoperibesion~chethpenimenthponimentponingoningonimentherion}}}\\\\ {{}}&{{}}&{{}}\\\\ {{\\mathrm{ouehpacinsisisisponsisispon~rnamaransisethensponusenisedusised}}}\\\\ {{}}&{{}}\\\\ {{\\mathrm{was~sithensedun~onsisisensinensensisinan~ruansisisedusen}}}\\\\ {{}}&{{\\mathrm{was~sighens~char~sisigusendus~singedusen}}}}\\end{array}'

# %%
from IPython.display import Image, display
display(Image(filename=source))
