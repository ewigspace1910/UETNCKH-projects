# %% [markdown]
# # ENV

# %%
# !pip install gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !gdown -O model.zip --id 1T8D5SAQagUf1toNumMMAjd4EZRBrhBwm
# !gdown -O question.zip --id 13lgLGcCQXv9bo2z-ZBjSmC_AZoGLh2XX
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1T8D5SAQagUf1toNumMMAjd4EZRBrhBwm
# To: /content/model.zip
# 100% 253M/253M [00:05<00:00, 49.8MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=13lgLGcCQXv9bo2z-ZBjSmC_AZoGLh2XX
# To: /content/question.zip
# 100% 151M/151M [00:02<00:00, 68.2MB/s]

# %%
# !unzip model.zip
# !unzip question.zip

# %%
# !conda create --name layoutlmv3 python=3.7
# !conda activate layoutlmv3
# %cd /content
# !git clone https://github.com/microsoft/unilm.git
# Out:
# /content
# Cloning into 'unilm'...
# remote: Enumerating objects: 7409, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 7409 (delta 48), reused 75 (delta 44), pack-reused 7317
# Receiving objects: 100% (7409/7409), 17.67 MiB | 2.87 MiB/s, done.
# Resolving deltas: 100% (3128/3128), done.

# %%
# %cd unilm/layoutlmv3
# !pip install -r requirements.txt

# %%
# install pytorch, torchvision refer to https://pytorch.org/get-started/locally/
# !pip install torch==1.12.0 torchvision==0.13.0+cu113 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# !python -m pip install detectron2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement detectron2 (from versions: none)
# ERROR: No matching distribution found for detectron2

# %%
# !pip install -e .

# %% [markdown]
# # **CODE**

# %% [markdown]
# ## ENV hyper

# %%
category_map = {
    "heading": 0, 
    "question": 1,  
    "subquestion": 2,
    "choice"  : 3,
    "image"   : 4,
    "table"   : 5,
    "blank"   : 6,
    "auxillary_text"   : 7
}
category_weights = {
    "heading": 3, 
    "question": 2,  
    "subquestion": 1,
    "choice"  : 0,
    "image"   : 0,
    "table"   : 0,
    "blank"   : 0,
    "auxillary_text"   : 0
}
reverse_map = {category_map[k]:k for k in category_map}

# %% [markdown]
# ## run

# %% [markdown]
# # TEST
