# %% [markdown]
# # YOLOv8

# %%
# !pip install gdown
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 8114, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 8114 (delta 130), reused 174 (delta 101), pack-reused 7887
# Receiving objects: 100% (8114/8114), 5.82 MiB | 23.92 MiB/s, done.
# Resolving deltas: 100% (5461/5461), done.

# %%
# !gdown -O best.pt --id 1Ne-Y4Oph0w_jcYiHqPki7gdUoir4Yv4B
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Ne-Y4Oph0w_jcYiHqPki7gdUoir4Yv4B
# To: /content/best.pt
# 100% 137M/137M [00:01<00:00, 129MB/s]

# %%
# %cd ultralytics
# Out:
# /content/ultralytics

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.5/584.5 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.3/203.3 kB 22.8 MB/s eta 0:00:00
# ...

# %%
# %cd /content
# !yolo export model=/content/best.pt format=onnx opset=12
# Out:
# /content
# Ultralytics YOLOv8.0.99 🚀 Python-3.10.11 torch-2.0.0+cu118 CPU
# YOLOv8x summary (fused): 268 layers, 68131272 parameters, 0 gradients, 257.4 GFLOPs
#
# PyTorch: starting from /content/best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 12, 8400) (130.4 MB)
# requirements: YOLOv8 requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 259.0 MB/s eta 0:00:00
# ...
#
# requirements: 1 package updated per ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.14.0 opset 12...
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ...

# %% [markdown]
# # OTHEr
