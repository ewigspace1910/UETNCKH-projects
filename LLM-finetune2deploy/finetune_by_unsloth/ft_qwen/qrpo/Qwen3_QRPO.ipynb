# %% [markdown]
# ### Unsloth

# %%
from unsloth import FastLanguageModel
import torch

fourbit_models = [
    "unsloth/Qwen3-1.7B-unsloth-bnb-4bit", # Qwen 14B 2x faster
    "unsloth/Qwen3-4B-unsloth-bnb-4bit",
    "unsloth/Qwen3-8B-unsloth-bnb-4bit",
    "unsloth/Qwen3-14B-unsloth-bnb-4bit",
    "unsloth/Qwen3-32B-unsloth-bnb-4bit",

    # 4bit dynamic quants for superior accuracy and low memory use
    "unsloth/gemma-3-12b-it-unsloth-bnb-4bit",
    "unsloth/Phi-4",
    "unsloth/Llama-3.1-8B",
    "unsloth/Llama-3.2-3B",
    "unsloth/orpheus-3b-0.1-ft-unsloth-bnb-4bit" # [NEW] We support TTS models!
] # More models at https://huggingface.co/unsloth
max_seq_length = 2048 # Can increase for longer reasoning traces
lora_rank = 64 # Larger rank = smarter, but slower
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen3-14B",
    max_seq_length = 2048,   # Context length - can be longer, but uses more memory
    load_in_4bit = True, # 4bit uses much less memory
    load_in_8bit = False,    # A bit more accurate, uses 2x memory
    full_finetuning = False, # We have full finetuning now!
    # fast_inference = True, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.85, # Reduce if out of memory
    # token = "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",      # use one if using gated models
)
model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank,           # Choose any number > 0! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = lora_rank,  # Best to choose alpha = rank or rank*2
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,   # We support rank stabilized LoRA
    loftq_config = None,  # And LoftQ
)

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
import json, re
def read_jsonfile(file_path="/home/ducanh/data/nemoWS/datasets/hey2/ielts-marking/raw_input4unsloth.json"):
    all_samples = []
    # Open and read the file line by line
    with open(file_path, "r", encoding="utf-8") as file:
        for line in file:
            data = json.loads(line)  # Parse the JSON object from each line
            # print(data)              # Do something with the JSON object
            all_samples += [data]
    return all_samples
def extract_hash_answer(text:str):
    if "boxed{" in text:
        pattern = r"\\boxed{(.+)}"
        matches = re.findall(pattern, text)
        if len(matches) == 0: print(text)
        text = matches[0]
        return text
    newtext=""
    for i in text:
        if i.isdigit(): newtext += i
    if newtext.strip() == "":
        print("Error-->", text)
        return None
    return newtext.strip()

import re
reasoning_start = "<think>"
reasoning_end   = "</think>"
solution_start = "<CONCLUSION>"
solution_end = "</CONCLUSION>"

system_prompt = \
f"""You are a IELTS Speaking Examiner.
Analysis question and corresponding student response then provide your comment.
Place it between {reasoning_start} and {reasoning_end}.
Then, provide the score from 0-9 between {solution_start}{solution_end}"""

def generate_conversation(examples):
    problems  = [example["input"].strip() for example in examples]
    solutions = [example["output"].strip() for example in examples]
    points = [extract_hash_answer(example["output"].strip()) for example in examples]
    conversations = []
    for problem, solution, point in zip(problems, solutions, points):
        if point is None:
            # print("\n--> SKIP output:", problem, solution)
            continue
        x = {
            "prompt" : [
                {"role": "system", "content": system_prompt},
                {"role": "user",   "content": problem},
            ],
            "answer": point, 'question': problem
        }
        conversations.append(x)
    return conversations
        # conversations.append([
        #     {"role" : "user",      "content" : problem},
        #     {"role" : "assistant", "content" : solution},
        # ])
    return { "conversations": conversations, }

ielts_datsets = read_jsonfile()
# my_reasoning_conversations = tokenizer.apply_chat_template(
#     generate_conversation(ielts_datsets)["conversations"],
#     tokenize = False,
# )
my_reasoning_conversations = generate_conversation(ielts_datsets)
print(my_reasoning_conversations[0])

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`.

# %%
match_format = re.compile(
    rf"^[\s]{{0,}}"\
    rf"{reasoning_start}.+?{reasoning_end}.*?"\
    rf"{solution_start}(.+?){solution_end}"\
    rf"[\s]{{0,}}$",
    flags = re.MULTILINE | re.DOTALL
)

match_format.search(
    "<start_working_out>Let me think!<end_working_out>"\
    "<SOLUTION>2</SOLUTION>",
)

# %%
match_format.search(
    "<think>Let me think!</think>"\
    "<SOLUTION>2</SOLUTION>",
)

# %%
def match_format_exactly(completions, **kwargs):
    scores = []
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        # Match if format is seen exactly!
        if match_format.search(response) is not None: score += 3.0
        scores.append(score)
    return scores

def match_format_approximately(completions, **kwargs):
    scores = []
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        # Count how many keywords are seen - we penalize if too many!
        # If we see 1, then plus some points!
        score += 0.5 if response.count(reasoning_start) == 1 else -1.0
        score += 0.5 if response.count(reasoning_end)   == 1 else -1.0
        score += 0.5 if response.count(solution_start)  == 1 else -1.0
        score += 0.5 if response.count(solution_end)    == 1 else -1.0
        scores.append(score)
    return scores

def check_answer(prompts, completions, answer, **kwargs):
    question = prompts[0][-1]["content"]
    responses = [completion[0]["content"] for completion in completions]

    extracted_responses = [
        guess.group(1)
        if (guess := match_format.search(r)) is not None else None \
        for r in responses
    ]

    scores = []
    for guess, true_answer in zip(extracted_responses, answer):
        score = 0
        if guess is None:
            scores.append(0)
            continue
        # Correct answer gets 3 points!
        if guess == true_answer:
            score += 3.0
        # Match if spaces are seen, but less reward
        elif guess.strip() == true_answer.strip():
            score += 1.5
        else:
            # We also reward it if the answer is close via ratios!
            # Ie if the answer is within some range, reward it!
            try:
                ratio = float(guess) / float(true_answer)
                if   ratio >= 0.9 and ratio <= 1.1: score += 1.0
                elif ratio >= 0.8 and ratio <= 1.2: score += 0.5
                else: score -= 1.5 # Penalize wrong answers
            except:
                score -= 1.5 # Penalize
        scores.append(score)
    return scores

# %%
import re
global PRINTED_TIMES
PRINTED_TIMES = 0
global PRINT_EVERY_STEPS
PRINT_EVERY_STEPS = 5
match_numbers = re.compile(
    solution_start + r".*?([\d\.\,]{1,})",
    flags = re.MULTILINE | re.DOTALL
)
def check_numbers(prompts, completions, answer, **kwargs):
    question = prompts[0][-1]["content"]
    responses = [completion[0]["content"] for completion in completions]

    extracted_responses = [
        guess.group(1)
        if (guess := match_numbers.search(r)) is not None else None \
        for r in responses
    ]

    scores = []
    # Print only every few steps
    global PRINTED_TIMES
    global PRINT_EVERY_STEPS
    if PRINTED_TIMES % PRINT_EVERY_STEPS == 0:
        print('*'*20, f"Question:\n{question}", f"\nAnswer:\n{answer[0]}", f"\nResponse:\n{responses[0]}", f"\nExtracted:\n{extracted_responses[0]}")
    PRINTED_TIMES += 1

    for guess, true_answer in zip(extracted_responses, answer):
        if guess is None:
            scores.append(0)
            continue
        # Convert to numbers
        try:
            true_answer = float(true_answer.strip())
            # Remove commas like in 123,456
            guess       = float(guess.strip().replace(",", ""))
            scores.append(1.5 if guess == true_answer else -0.5)
        except:
            scores.append(0)
            continue
    return scores

# %%
max_prompt_length = 400 + 1 # + 1 just in case!
max_seq_length=2048
from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    learning_rate = 5e-6,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "adamw_torch_fused",
    logging_steps = 1,
    per_device_train_batch_size = 2,
    gradient_accumulation_steps = 4, # Increase to 4 for smoother training
    num_generations = 8, # Decrease if out of memory
    max_prompt_length = max_prompt_length,
    max_completion_length = max_seq_length - max_prompt_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 2000,
    save_steps = 250,
    max_grad_norm = 0.1,
    report_to = "none", # Can use Weights & Biases
    output_dir = "/home/ducanh/nvidia-llm-pipeline/unslot/ft_qwen/qrpo/outputs",
)
trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        match_format_exactly,
        match_format_approximately,
        check_answer,
        check_numbers,
    ],
    args = training_args,
    train_dataset = my_reasoning_conversations,
)
trainer.train()
# Out:
# ******************** Question:
# Evaluate the following answer(s) for IELTS speaking test for the rubric "Grammatical Range and Accuracy".
#
# Items to be evaluated:
# IELTS speaking test part: Part 3
# Topic: Culinary Traditions and Identity
# Questions:
# How do culinary traditions contribute to cultural identity?
# What role does food play in bringing people together during celebrations?
# Can culinary traditions evolve while still preserving their essence?
# How has globalization affected local culinary traditions around the world?
#
# Answers:
# Culinary traditions contribute to cultural identity by reflecting the unique ingredients, cooking methods, and flavors that are passed down through generations, helping people feel connected to their heritage.
# Food plays a central role in bringing people together during celebrations as sharing meals fosters a sense of community, strengthens relationships, and creates joyful experiences.
# Yes, culinary traditions can evolve by incorporating new influences or adapting to modern tastes while still preserving the core elements that define them.
# Globalization has both positive and negative effects on local culinary traditions; it introduces new foods and ideas but can also lead to the loss of traditional recipes and practices.
# Answer:
# 5
# Response:
# <think>
# Okay, let's analyze the student's answers for the "Grammatical Range and Accuracy" band score in IELTS Speaking Part 3.
#
# First, I need to look at the grammatical structures used. The student uses a variety of sentence structures, including complex sentences with subordinate clauses. For example, in the first answer, they use "by reflecting the unique ingredients, cooking methods, and flavors that are passed down through generations." This shows the use of a relative clause, which is a more advanced structure.
#
# In the second answer, the student uses a complex sentence: "Food plays a central role in bringing people together during celebrations as sharing meals fosters a sense of community, strengthens relationships, and creates joyful experiences." Here, the student uses a conjunction 'as' to link two clauses and includes a list with commas, which is correct. The verbs 'fosters', 'strengthens', and 'creates' are all in the base form after 'as', which is appropriate.
#
# The third answer starts with "Yes, culinary traditions can evolve by incorporating new influences or adapting to modern tastes while still preserving the core elements that define them." The use of 'by incorporating' and 'adapting' shows the ability to use different verb forms. The 'while' clause correctly contrasts the evolution with preservation.
#
# In the fourth answer, the student uses a complex structure: "Globalization has both positive and negative effects on local culinary traditions; it introduces new foods and ideas but can also lead to the loss of traditional recipes and practices." The semicolon is correctly used to join two independent clauses, and the contrast is shown with 'but'. The use of 'can also lead to' is correct, showing the potential negative effect.
#
# Now, looking for errors: The student uses correct tenses, subject-verb agreement, and prepositions. There are no obvious grammatical mistakes. The sentences are varied in structure, showing a good range of grammatical knowledge. The student effectively uses conjunctions and relative clauses to link ideas.
#
# The only minor point is the use of 'can also lead to' which is slightly repetitive in structure, but this is a very minor issue and doesn't affect the overall score. The student demonstrates a strong command of grammar with accurate use of complex structures, which is suitable for a high band score.
#
# I would rate this answer a 7.5 or 8 in Grammatical Range and Accuracy because the student consistently uses a variety of structures correctly with minimal errors, showing good control and flexibility in grammar.
# </think>
#
# <CONCLUSION>8</CONCLUSION>
# Extracted:
# 8
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='67' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  67/2000 9:20:07 < 277:37:10, 0.00 it/s, Epoch 0.05/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completion_length</th>
#       <th>kl</th>
#       <th>rewards / match_format_exactly</th>
#       <th>rewards / match_format_approximately</th>
#       <th>rewards / check_answer</th>
#       <th>rewards / check_numbers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>3.125000</td>
#       <td>0.727011</td>
#       <td>766.812500</td>
#       <td>0.000000</td>
#       <td>2.250000</td>
#       <td>1.250000</td>
#       <td>-0.406250</td>
#       <td>0.031250</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-0.000000</td>
#       <td>2.140625</td>
#       <td>0.275649</td>
#       <td>733.906250</td>
#       <td>0.000000</td>
#       <td>2.250000</td>
#       <td>1.250000</td>
#       <td>-1.000000</td>
#       <td>-0.359375</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>3.343750</td>
#       <td>0.273453</td>
#       <td>732.437500</td>
#       <td>0.000446</td>
#       <td>2.250000</td>
#       <td>1.250000</td>
#       <td>-0.296875</td>
#       <td>0.140625</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>2.765625</td>
#       <td>0.520170</td>
#       <td>773.656250</td>
#       <td>0.000494</td>
#       <td>2.250000</td>
#       <td>1.250000</td>
#       <td>-0.375000</td>
#       <td>-0.359375</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>4.484375</td>
#       <td>1.257046</td>
#       <td>660.562500</td>
#       <td>0.000427</td>
#       <td>3.000000</td>
#       <td>1.906250</td>
#       <td>-0.312500</td>
#       <td>-0.109375</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>4.343750</td>
#       <td>0.653566</td>
#       <td>536.250000</td>
#       <td>0.000492</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>-0.312500</td>
#       <td>-0.343750</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>4.296875</td>
#       <td>0.787711</td>
#       <td>563.812500</td>
#       <td>0.000492</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>-0.296875</td>
#       <td>-0.406250</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>3.453125</td>
#       <td>0.858363</td>
#       <td>524.218750</td>
#       <td>0.000504</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>-1.171875</td>
#       <td>-0.375000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>4.140625</td>
#       <td>0.954251</td>
#       <td>521.625000</td>
#       <td>0.000540</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>-0.625000</td>
#       <td>-0.234375</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>3.734375</td>
#       <td>1.028268</td>
#       <td>556.406250</td>
#       <td>0.000484</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>-1.078125</td>
#       <td>-0.187500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>5.312500</td>
#       <td>1.555909</td>
#       <td>610.468750</td>
#       <td>0.000432</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>0.375000</td>
#       <td>-0.062500</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>3.656250</td>
#       <td>0.929651</td>
#       <td>574.937500</td>
#       <td>0.000421</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>-0.937500</td>
#       <td>-0.406250</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>3.296875</td>
#       <td>0.527686</td>
#       <td>596.843750</td>
#       <td>0.000478</td>
#       <td>2.906250</td>
#       <td>1.953125</td>
#       <td>-1.093750</td>
#       <td>-0.468750</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>3.531250</td>
#       <td>0.690313</td>
#       <td>739.250000</td>
#       <td>0.000454</td>
#       <td>2.250000</td>
#       <td>1.250000</td>
#       <td>0.250000</td>
#       <td>-0.218750</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>2.640625</td>
#       <td>0.849570</td>
#       <td>745.343750</td>
#       <td>0.000476</td>
#       <td>2.250000</td>
#       <td>1.250000</td>
#       <td>-0.578125</td>
#       <td>-0.281250</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>4.765625</td>
#       <td>1.544505</td>
#       <td>567.593750</td>
#       <td>0.000447</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>-0.171875</td>
#       <td>-0.062500</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000000</td>
#       <td>4.171875</td>
#       <td>1.158341</td>
#       <td>815.062500</td>
#       <td>0.000457</td>
#       <td>2.250000</td>
#       <td>1.250000</td>
#       <td>0.609375</td>
#       <td>0.062500</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000000</td>
#       <td>3.031250</td>
#       <td>0.088388</td>
#       <td>534.531250</td>
#       <td>0.000490</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>-1.500000</td>
#       <td>-0.468750</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000000</td>
#       <td>4.609375</td>
#       <td>1.594455</td>
#       <td>656.687500</td>
#       <td>0.000454</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>-0.218750</td>
#       <td>-0.171875</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000000</td>
#       <td>3.312500</td>
#       <td>0.514909</td>
#       <td>567.375000</td>
#       <td>0.000483</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>-1.281250</td>
#       <td>-0.406250</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000000</td>
#       <td>3.031250</td>
#       <td>0.494388</td>
#       <td>862.656250</td>
#       <td>0.000469</td>
#       <td>2.250000</td>
#       <td>1.250000</td>
#       <td>-0.203125</td>
#       <td>-0.265625</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.000000</td>
#       <td>4.203125</td>
#       <td>1.042110</td>
#       <td>561.968750</td>
#       <td>0.000515</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>-0.625000</td>
#       <td>-0.171875</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.000000</td>
#       <td>4.859375</td>
#       <td>1.674027</td>
#       <td>561.375000</td>
#       <td>0.000482</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>0.031250</td>
#       <td>-0.171875</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.000000</td>
#       <td>3.140625</td>
#       <td>0.397748</td>
#       <td>510.156250</td>
#       <td>0.000506</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>-1.375000</td>
#       <td>-0.484375</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.000000</td>
#       <td>3.421875</td>
#       <td>0.582243</td>
#       <td>508.937500</td>
#       <td>0.000495</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>-1.125000</td>
#       <td>-0.453125</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.000000</td>
#       <td>5.093750</td>
#       <td>1.068379</td>
#       <td>607.593750</td>
#       <td>0.000484</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>0.328125</td>
#       <td>-0.234375</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.000000</td>
#       <td>2.281250</td>
#       <td>0.298070</td>
#       <td>804.500000</td>
#       <td>0.000452</td>
#       <td>2.250000</td>
#       <td>1.250000</td>
#       <td>-0.875000</td>
#       <td>-0.343750</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.000000</td>
#       <td>4.718750</td>
#       <td>1.120011</td>
#       <td>554.281250</td>
#       <td>0.000440</td>
#       <td>3.000000</td>
#       <td>2.000000</td>
#       <td>-0.109375</td>
#       <td>-0.171875</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.000000</td>
#       <td>3.093750</td>
#       <td>0.669190</td>
#       <td>733.062500</td>
#       <td>0.000493</td>
#       <td>2.250000</td>
#       <td>
# ******************** Question:
# Evaluate the following answer(s) for IELTS speaking test for the rubric "Grammatical Range and Accuracy".
#
# Items to be evaluated:
# IELTS speaking test part: Part 3
# Topic: Aging Population
# Questions:
# What are some challenges faced by an aging population?
# How can societies better support their elderly citizens?
# Do you think the government should invest more in programs for the elderly? Why or why not?
# What role do families play in caring for older relatives?
#
# Answers:
# Old people have many problem like health and no work.
# Society can help old with hospital and food and home.
# Government should give money for old people because they need help.
# Family is important for old people. They take care and love.
# Answer:
# 1
# Response:
# <think>
# Okay, let me evaluate the student's answers for the "Grammatical Range and Accuracy" rubric in the IELTS Speaking test. The topic is the aging population, and the student has answered four questions.
#
# First, I'll look at each answer individually. For the first question, the student says, "Old people have many problem like health and no work." There are several grammatical errors here. "Problem" should be plural "problems," and "like health and no work" is a bit unclear. The structure is simple and lacks variety.
#
# Second answer: "Society can help old with hospital and food and home." This sentence has incorrect prepositions. It should be "help the elderly with hospitals, food, and home care." Also, "home" is too vague. The grammar is very basic with limited sentence structures.
#
# Third answer: "Government should give money for old people because they need help." Here, "Government" needs a capital letter and "old people" should be "the elderly" for formality. The sentence is correct in structure but lacks complexity and uses very simple vocabulary.
#
# Fourth answer: "Family is important for old people. They take care and love." This is two sentences. The first is okay, but "take care and love" is unclear. It should be "take care of them and show them love." The grammar is basic and lacks variety.
#
# Overall, the student uses very simple sentence structures and has many grammatical errors. There's little use of complex grammar or varied sentence structures. The vocabulary is also limited and repetitive. Since the student makes frequent errors in grammar and uses simple structures, this would score low on the "Grammatical Range and Accuracy" rubric.
#
# I think the score would be around 4.5 because the student attempts to answer the questions but with significant errors and limited use of grammar.
# </think>
#
# <CONCLUSION>
# The student's response demonstrates a very limited range of grammatical structures and frequent inaccuracies. The sentences are predominantly simple, with minimal use of complex grammar, and numerous errors in subject-verb agreement (e.g., "Old people have many problem"), prepositions (e.g., "help old with hospital"), article usage (e.g., "government should give money for old people"), and noun forms (e.g., "no work" instead of "lack of work"). The vocabulary is also basic and repetitive, with little attempt to vary sentence structure or use advanced grammar. This response would likely score **4.5** on the "Grammatical Range and Accuracy" rubric.
# </CONCLUSION>
# Extracted:
# .
# ******************** Question:
# Evaluate the following answer(s) for IELTS speaking test for the rubric "Grammatical Range and Accuracy"
#
# Items to be evaluated:
# IELTS speaking test part: Part 2
# Topic: -
# Question: Talk about a person from history whose life story fascinates you and why.
# ```
# Answers for evaluating Grammatical Range and Accuracy:
# Answer:
# I am interested in Mahatma Gandhi. He used nonviolent protest to help India gain independence. This approach was unusual but effective. He showed strong belief and discipline. I admire him because he changed the world without violence.
# ```
#  Please think step-by-step.
# Answer:
# 5
# Response:
# <think>
# Okay, let's evaluate the student's answer for Grammatical Range and Accuracy in the IELTS Speaking Part 2. The topic is about a person from history whose life story fascinates them, specifically Mahatma Gandhi.
#
# First, I'll check the grammar. The student uses simple sentences, like "I am interested in Mahatma Gandhi." Then, "He used nonviolent protest to help India gain independence." That's correct. Next, "This approach was unusual but effective." The use of "but" here is correct for contrast.
#
# They mention "He showed strong belief and discipline." The verb "showed" is correct here. Then, "I admire him because he changed the world without violence." The structure "because he changed" is appropriate.
#
# Looking for complexity: The sentences are mostly simple and compound. There's no use of complex structures like relative clauses or conditional sentences. The vocabulary is straightforward.
#
# Are there any errors? The sentence "He used nonviolent protest to help India gain independence" is correct. "This approach was unusual but effective" is also correct. "He showed strong belief and discipline" – "belief" here is a noun, but it's better to say "he showed a strong belief" or "he believed strongly," but as a noun, it's acceptable. However, "belief" might be better as a gerund or with an article.
#
# The student uses "nonviolent" as an adjective, which is correct. The final sentence uses "without violence," which is correct.
#
# So, the grammar is mostly accurate with simple structures. There's no significant error. However, there's limited use of complex structures. The vocabulary is appropriate but not very varied.
#
# For Grammatical Range and Accuracy, the student uses a range of simple and compound sentences but doesn't use complex structures. The accuracy is good with few or no errors.
#
# In IELTS, a score of 6.5 might be given for adequate use of grammar with some errors. However, since the errors are minimal and the structures are mostly correct, maybe a 7.0? But the range is limited. Wait, the student doesn't use any complex sentences like relative clauses or conditional structures. That might limit the score. So maybe a 6.5? But the accuracy is high.
#
# I think the student has a 6.5 for Grammatical Range and Accuracy. They have a few simple structures, correct grammar, minimal errors, but not a wide range of structures.
# </think>
#
# <CONCLUSION>6.5</CONCLUSION>
# Extracted:
# 6.5
# ******************** Question:
# Evaluate the following answer(s) for IELTS speaking test for the rubric "Lexical Resource".
#
# Items to be evaluated:
# IELTS speaking test part: Part 2
# Topic: -
# Question: Describe a memorable encounter with a stranger. What happened and how did it affect you?
#
# Answer:
# Once, I had an encounter with a stranger on the train. He noticed I was lost and kindly gave me directions to my destination. This small act of kindness made me feel more confident and trusting of others.
#
# CTTR: 3.9
# Answer:
# 5
# Response:
# <think>
# Okay, let's start by analyzing the student's answer for the "Lexical Resource" rubric in the IELTS Speaking Part 2. The answer provided is: "Once, I had an encounter with a stranger on the train. He noticed I was lost and kindly gave me directions to my destination. This small act of kindness made me feel more confident and trusting of others."
#
# First, I need to assess the range and accuracy of vocabulary used. The student uses basic vocabulary such as "encounter," "stranger," "train," "lost," "directions," "act of kindness," "confident," and "trusting." These words are all relevant to the topic and are used correctly. However, there's a lack of more advanced or varied vocabulary. Words like "encounter" and "kindly" are appropriate, but there's little evidence of more sophisticated terms that could demonstrate a higher lexical resource.
#
# Next, I should check for any collocations or phrasal verbs that might be missing. The student uses "gave me directions" which is a common collocation, but there's no use of more complex phrases or idiomatic expressions. The vocabulary is straightforward and doesn't show the ability to use less common words effectively.
#
# The answer is concise and stays on topic, but the vocabulary doesn't go beyond basic terms. The student doesn't use any synonyms or paraphrase effectively, which might limit the score. For example, instead of "act of kindness," they could have used "gesture of goodwill" or "generous act," but they didn't. Also, the structure is simple, with no complex sentence structures that might require more advanced vocabulary.
#
# Considering the band score descriptors for Lexical Resource, a score of 3.9 suggests that the student has a limited vocabulary, with noticeable errors in word choice and collocation. However, in this case, the answer doesn't have obvious errors but lacks the range and sophistication expected for a higher band. The vocabulary is accurate but not varied enough to merit a higher score.
#
# Therefore, the Lexical Resource score seems appropriate as 3.9 because the student uses basic vocabulary accurately but with little variation and no advanced terms, which is typical for a lower band score in this rubric.
# </think>
#
# <CONCLUSION>3.9</CONCLUSION>
# Extracted:
# 3.9
# ******************** Question:
# Evaluate the following answer(s) for IELTS speaking test for the rubric "Grammatical Range and Accuracy".
#
# Items to be evaluated:
# IELTS speaking test part: Part 2
# Topic: -
# Question: Describe a place you would like to visit in the future. Why do you want to go there?
#
# Answer:
# One place I would really like to visit in the future is Japan. The reason is that I am fascinated by Japanese culture, especially their traditions and modern technology. Also, I have heard that the food there is amazing, so I would love to try authentic Japanese cuisine.
# Answer:
# 6
# Response:
# <think>
# Okay, let's evaluate this answer for the "Grammatical Range and Accuracy" rubric in IELTS Speaking Part 2. The student is describing a place they want to visit in the future, which is Japan, and the reasons why.
#
# First, I need to check for grammatical accuracy. The answer uses simple and compound sentences. The first sentence is "One place I would really like to visit in the future is Japan." The structure here is correct. "Would like to visit" is properly used. The second sentence starts with "The reason is that..." which is a bit formal but acceptable. Then "I am fascinated by Japanese culture, especially their traditions and modern technology." This is a compound sentence with a relative clause "especially their traditions and modern technology." The use of "especially" is correct.
#
# Next, the third sentence: "Also, I have heard that the food there is amazing, so I would love to try authentic Japanese cuisine." Here, "also" is correctly placed at the beginning. The conjunction "so" is used to show the result of hearing that the food is amazing. "Authentic" is correctly used to modify "Japanese cuisine."
#
# Looking for any errors: The tenses used are appropriate. "Would like to visit" is future intention. "Have heard" is present perfect, which is correct. "Is" is present tense for the food being amazing. The use of "there" is correct as a place reference. The prepositions "by" and "of" are correctly used in "fascinated by" and "Japanese culture."
#
# Now, for grammatical range. The student uses a variety of sentence structures: simple (One place... is Japan), compound (The reason is that... and especially...), complex (I have heard that the food... so I would love to try...). They also use some adjectives and adverbs appropriately. However, the range is limited. There's not a lot of variation in sentence structures beyond simple and compound sentences. They don't use any advanced structures like relative clauses beyond what's necessary, or subjunctive mood, or complex subordinate clauses. The vocabulary is also straightforward but accurate.
#
# Accuracy-wise, there are no obvious errors. All verbs are correctly conjugated, subject-verb agreement is maintained, and prepositions are used appropriately. The student avoids any major grammatical mistakes.
#
# Considering the IELTS band descriptors for "Grammatical Range and Accuracy," a score of 6.5 might be appropriate here. The student uses a variety of sentence structures with some complexity but limited use of more advanced structures. They make very few errors in grammar and use a range of vocabulary. However, the range of grammar structures isn't extensive, and there's no use of more complex sentences beyond simple and compound ones. So, they meet the criteria for a 6.5 but don't quite reach 7 because the grammatical range is limited.
# </think>
#
# <CONCLUSION>6.5</CONCLUSION>
# Extracted:
# 6.5
# ******************** Question:
# Evaluate the following answer(s) for IELTS speaking test for the rubric "Lexical Resource".
#
# Items to be evaluated:
# IELTS speaking test part: Part 3
# Topic: Innovation and Creativity
# Questions:
# What is the relationship between innovation and creativity in society?
# How can businesses foster a culture of creativity among their employees?
# Do you think creativity can be taught, or is it inherent?
# What are the potential downsides of innovation in today's world?
#
# Answers:
# Innovation and creativity are connected because creativity is the source of new ideas, and innovation is the process of applying those ideas in society to improve things.
# Businesses can foster creativity by creating an open environment where employees feel safe to express ideas and by providing resources for experimentation.
# I believe creativity is partly inherent but also can be developed through education and practice.
# Potential downsides of innovation include job displacement due to automation, environmental harm, and increased social divides.
#
# CTTR: 4.822
# Answer:
# 5
# Response:
# <think>
# Okay, let me start by analyzing the student's answers for the Lexical Resource rubric in IELTS Speaking Part 3. The topic is Innovation and Creativity, and the student answered four questions.
#
# First, the vocabulary used. The student uses terms like "connected," "source of new ideas," "process of applying," "improve things," "open environment," "safe to express," "resources for experimentation," "partly inherent," "developed through education and practice," "job displacement," "automation," "environmental harm," and "social divides." These are all relevant to the topic and show some specific terminology related to innovation and creativity.
#
# Looking at lexical range, the student uses a variety of vocabulary, but there are some repeated words. For example, "creativity" and "innovation" are used multiple times. Also, phrases like "improve things" and "safe to express" are straightforward. The student could have used more varied synonyms or more complex expressions to enhance lexical resource.
#
# Collocation and accuracy: The student uses some collocations like "open environment," "safe to express ideas," "resources for experimentation," which are appropriate. However, there are minor errors. For example, "potential downsides of innovation" is a bit vague; specifying "negative impacts" or "consequences" could be better. Also, "increased social divides" is a bit abrupt; maybe "widen social inequalities" would be more precise.
#
# Use of academic vocabulary: The student uses terms like "job displacement," "environmental harm," "social divides," which are relevant. However, the vocabulary isn't always academic enough. For example, "improve things" is too informal. Using "enhance societal well-being" or "improve quality of life" would be more appropriate in a speaking test.
#
# Range of vocabulary: The student covers different aspects of innovation and creativity but could expand more. Terms like "creative thinking," "innovative solutions," "technological advancements," or "disruptive technologies" might add depth.
#
# Precision and clarity: The answers are clear but sometimes lack precision. For instance, "job displacement due to automation" is clear, but explaining how automation leads to job loss could be more detailed. The student could also use more specific examples or explain concepts more thoroughly.
#
# Overall, the student uses a sufficient range of vocabulary related to the topic, but there's room for improvement in terms of variety, academic tone, and precision. The errors are minor but could affect the score. Based on these points, the lexical resource score would be around 6.5, considering the appropriate vocabulary, some collocations, but with limited range and minor inaccuracies.
# </think>
#
# <CONCLUSION>6.5</CONCLUSION>
# Extracted:
# 6.5
# ******************** Question:
# Evaluate the following answer(s) for IELTS speaking test for the rubric "Lexical Resource".
#
# Items to be evaluated:
# IELTS speaking test part: Part 2
# Topic: -
# Question: Describe a time when you had to teach someone a skill. What was the skill and how did you approach it?
#
# Answer:
# Some months ago, I taught a friend how to play the guitar, which was quite challenging since he had no prior experience. I started with the basics—holding the instrument correctly, tuning the strings, and simple chords. I used a step-by-step approach, combining demonstrations with practice sessions, and encouraged him to be patient with himself as learning an instrument takes time.
#
# CTTR: 4.473
# Answer:
# 8
# Response:
# <think>
# Okay, let me analyze the student's answer for the "Lexical Resource" rubric in IELTS Speaking Part 2. The task is to describe a time when they taught someone a skill.
#
# First, I'll look at the vocabulary used. The student mentions teaching a friend to play the guitar, starting with basics like holding the instrument, tuning strings, and simple chords. They also talk about a step-by-step approach, demonstrations, practice sessions, and encouraging patience.
#
# The vocabulary here is generally appropriate for the topic. Words like "instrument," "tuning," "chords," "step-by-step approach," "demonstrations," and "practice sessions" are relevant. The student uses some academic or formal terms like "prior experience," "encouraged him to be patient," and "takes time." These are good for a speaking test, showing a range of vocabulary.
#
# However, there's a lack of more specific or varied vocabulary. Phrases like "step-by-step approach" are common and could be replaced with more precise terms, like "structured methodology" or "gradual progression." Also, there are some repetitive structures, such as using "how to play the guitar" and "learning an instrument," which could be phrased more diversely.
#
# The student uses some collocations that are correct, like "prior experience," "encouraged him to be patient." However, there's not much in the way of idiomatic expressions or less common vocabulary that would elevate the score. The answer is clear and uses appropriate terms, but it doesn't showcase a wide range of vocabulary or sophisticated expressions.
#
# There are no significant errors in word choice, but the vocabulary is somewhat basic and lacks the variety and complexity that would be expected for a higher band score. The student could have used more precise terms related to teaching methods or guitar playing to demonstrate a richer lexical resource.
#
# Overall, the lexical resource is adequate but limited. The answer is clear and uses appropriate vocabulary, but there's room for more varied and sophisticated language to achieve a higher score.
# </think>
#
# <CONCLUSION>
# The student's answer demonstrates an adequate range of vocabulary relevant to the topic, with appropriate use of terms such as "step-by-step approach," "demonstrations," and "patience." However, the lexical resource is somewhat limited, with repetitive structures (e.g., "learning an instrument takes time" vs. "he had no prior experience") and a lack of more sophisticated or nuanced vocabulary (e.g., "structured methodology" instead of "step-by-step approach"). While the answer is clear and free of significant errors, the limited lexical variety and lack of idiomatic expressions prevent it from reaching a higher score.
# </CONCLUSION>
# Score: **6.0**
# Extracted:
# ,
# ******************** Question:
# Evaluate the following answer(s) for IELTS speaking test for the rubric "Grammatical Range and Accuracy".
#
# Items to be evaluated:
# IELTS speaking test part: Part 2
# Topic: -
# Question: Talk about a time when you had to give a presentation. What was the topic and how did you prepare for it?
#
# Answer:
# I gave a presentation last month about environmental problems. To prepare, I researched online and wrote key points on cards. I practiced speaking several times to feel more confident, but I still made some mistakes during the presentation.
# Answer:
# 5
# Response:
# <think>
# Okay, let's analyze the student's answer for the "Grammatical Range and Accuracy" rubric in IELTS Speaking Part 2. The topic is about a time when the student had to give a presentation.
#
# First, I'll look at the grammatical structures used. The answer uses simple past tense throughout, which is appropriate for recounting a past event. There are a few basic sentence structures: "I gave a presentation...", "To prepare, I researched...", "I practiced speaking...", "I still made some mistakes...". These are straightforward and correct, but there's a lack of complex structures like conditional sentences, passive voice, or complex noun phrases.
#
# Next, I'll check for accuracy. The tenses are consistent, and the sentences are grammatically correct. However, there's a minor issue with the use of "practiced speaking several times" – it's correct, but "practiced" is the past tense of "practice," which is correct here. No obvious grammatical errors are present.
#
# The student's answer doesn't use a variety of sentence structures. All sentences are simple or compound, but there's no use of complex sentences or advanced grammatical features like relative clauses or participial phrases. This limits the range of grammatical structures used.
#
# In terms of vocabulary, the answer is clear and accurate, but it doesn't showcase a wide range of vocabulary. However, the question is about grammar, so vocabulary isn't the focus here.
#
# Overall, the student's answer is grammatically accurate but lacks variety in sentence structures. They stick to simple past tense and basic sentence forms. This would likely score in the mid-range for Grammatical Range and Accuracy, maybe a 6.0 or 6.5, depending on the examiner's leniency towards the lack of complexity.
# </think>
#
# <CONCLUSION>6.0</CONCLUSION>
# Extracted:
# 6.0
# ******************** Question:
# Evaluate the following answer(s) for IELTS speaking test for the rubric "Grammatical Range and Accuracy".
#
# Items to be evaluated:
# IELTS speaking test part: Part 1
# Topic: Arts and Crafts
# Questions:
# Do you enjoy doing any crafts or artistic activities?
# What type of art or craft do you find most appealing?
# How do you think participating in arts and crafts benefits people?
# Have you ever taken a class to improve your artistic skills?
#
# Answers:
# Yes, I really enjoy doing crafts like painting and making handmade decorations in my spare time.
# Painting is the type of art that attracts me the most because it allows for a lot of creative freedom and expression.
# Engaging in arts and crafts can benefit people by improving their mental well-being and helping them develop fine motor skills.
# While I haven't taken any formal classes, I've participated in workshops that helped me enhance my artistic abilities.
#
# Topic: Time Management and Organization
# Questions:
# How do you prioritize your tasks during the day?
# What strategies do you use to manage your time effectively?
# Do you think being organized is important for success? Why or why not?
# How has technology impacted the way we manage our time?
#
# Answers:
# I usually prioritize my daily tasks by assessing their urgency and importance, ensuring critical ones are done first.
# My strategies for effective time management include using digital calendars, setting reminders, and breaking tasks into smaller parts.
# Being organized is crucial for success because it enables better focus, reduces stress, and ensures deadlines are met efficiently.
# Technology has transformed how we manage time by providing tools such as scheduling apps and notifications that keep us on track.
# Answer:
# 7
# Response:
# <think>
# Okay, I need to evaluate the student's answers for the IELTS Speaking test, specifically focusing on "Grammatical Range and Accuracy." Let me go through each answer carefully.
#
# First, looking at the Arts and Crafts topic. The student answers the questions with clear, straightforward sentences. In the first answer, they use "I really enjoy doing crafts like painting and making handmade decorations in my spare time." The grammar here is correct, with appropriate use of prepositions and tenses. The second answer: "Painting is the type of art that attracts me the most because it allows for a lot of creative freedom and expression." The structure is complex with a relative clause, which shows range. The third answer: "Engaging in arts and crafts can benefit people by improving their mental well-being and helping them develop fine motor skills." This uses a gerund phrase and a subordinate clause. The last answer: "While I haven't taken any formal classes, I've participated in workshops that helped me enhance my artistic abilities." This uses a contrast conjunction and a past perfect tense. There are no obvious errors here, so grammatical accuracy is good, and there's a range of structures.
#
# Moving to the Time Management and Organization topic. The first answer: "I usually prioritize my daily tasks by assessing their urgency and importance, ensuring critical ones are done first." The structure is complex with a participle phrase. Second answer: "My strategies for effective time management include using digital calendars, setting reminders, and breaking tasks into smaller parts." This uses a list with conjunctions and a noun phrase. Third answer: "Being organized is crucial for success because it enables better focus, reduces stress, and ensures deadlines are met efficiently." Again, complex structure with a relative clause and a list. Fourth answer: "Technology has transformed how we manage time by providing tools such as scheduling apps and notifications that keep us on track." This uses a complex sentence with a participle phrase. No grammatical errors are evident, and there's a variety of sentence structures and vocabulary.
#
# Now, checking for errors. In the first topic, all sentences are grammatically correct. In the second topic, "ensuring critical ones are done first" uses a participle correctly. "Reducing stress" is a gerund, which is appropriate. The use of "has transformed how we manage time" is correct. There are no errors that I can spot. The student uses a range of sentence structures, including complex sentences with relative clauses, gerunds, and participles. The vocabulary is appropriate and varied, which contributes to a good score in grammatical range and accuracy.
#
# The student's performance seems to be around a 7.5 or 8. They use a variety of structures correctly without errors. However, I should check if there's any repetition in structure. For example, the use of "by + verb-ing" structures in both topics. But overall, the accuracy is high, and the range is sufficient. Maybe there's a minor issue with some sentence structures being similar, but that's not a major deduction. The score is likely 7.5 or 8.5, but I need to confirm based on the IELTS criteria. Since there are no errors and a good range, I think 8 is appropriate.
# </think>
#
# <CONCLUSION>8</CONCLUSION>
# Extracted:
# 8
# ******************** Question:
# Evaluate the following answer(s) for IELTS speaking test for the rubric "Grammatical Range and Accuracy".
#
# Items to be evaluated:
# IELTS speaking test part: Part 1
# Topic: Personal Finance
# Questions:
# How do you usually manage your finances?
# What advice would you give someone about saving money?
# Do you think it is important to budget your expenses? Why?
# Have you ever faced any financial challenges, and how did you handle them?
#
# Answers:
# I try to keep track of my money but sometimes forget. Mostly, I save some money in bank account.
# My advice for saving money is to not spend on things not necessary and keep some money for future.
# Yes, budgeting is important because if you don’t plan, you can spend too much and have no money later.
# Once, I had problem with money when unexpected bills come. I asked family for help and tried to spend less.
#
# Topic: Local History
# Questions:
# Are you interested in the history of your local area? Why or why not?
# What is a historical site in your area that you find interesting?
# How do you usually learn about local history?
# Do you think local history is important for community identity?
#
# Answers:
# Yes, I like local history because it tells stories about my town and people before us.
# There is an old fort near my home which was built many years ago. It looks very old but nice.
# I learn about local history by reading books and sometimes watching documentaries on TV.
# Local history is important because it helps people feel connected and proud of their community.
# Answer:
# 4
# Response:
# <think>
# Okay, let's tackle this IELTS Speaking Part 1 evaluation for the "Grammatical Range and Accuracy" rubric. The candidate's answers are in two topics: Personal Finance and Local History. I need to assess their use of grammar in terms of variety and accuracy.
#
# Starting with Personal Finance. The first answer: "I try to keep track of my money but sometimes forget. Mostly, I save some money in bank account." Here, the grammar is mostly simple. "Try to keep track" is correct. "But sometimes forget" uses a conjunction correctly. The second sentence uses "mostly" correctly but the preposition "in" might be incorrect; it should be "in a bank account" or "in the bank." Also, "save some money in bank account" is missing an article.
#
# Next answer: "My advice for saving money is to not spend on things not necessary and keep some money for future." The structure here is a bit awkward. "To not spend" is more natural as "not to spend." "On things not necessary" is a bit clunky; "unnecessary things" is smoother. "For future" should be "for the future."
#
# Third answer: "Yes, budgeting is important because if you don’t plan, you can spend too much and have no money later." The grammar here is mostly correct. The conditional structure "if you don’t plan" is correct. The conjunction "and" connects two results correctly.
#
# Fourth answer: "Once, I had problem with money when unexpected bills come. I asked family for help and tried to spend less." "Had problem" should be "had a problem." "When unexpected bills come" is in the present tense, which is incorrect because the event is in the past; it should be "when unexpected bills came." "Tried to spend less" is correct.
#
# Moving to Local History topic. First answer: "Yes, I like local history because it tells stories about my town and people before us." The structure is correct. "People before us" is a bit awkward; "people who lived before us" might be better, but it's understandable.
#
# Second answer: "There is an old fort near my home which was built many years ago. It looks very old but nice." The relative clause "which was built" is correct. "But nice" is a bit abrupt; "but it looks nice" would be more natural.
#
# Third answer: "I learn about local history by reading books and sometimes watching documentaries on TV." Correct use of "by + verb-ing" structure. "Sometimes watching" is correct.
#
# Fourth answer: "Local history is important because it helps people feel connected and proud of their community." The structure is correct. "Feel connected and proud" is a good use of adjectives.
#
# Overall, the candidate uses a range of simple and compound sentences, but there are some errors in prepositions, articles, and verb tenses. The vocabulary is functional, and the grammar is not overly complex, which is typical for Band 5.5-6.5. However, the candidate avoids major grammatical errors and uses a variety of structures, which might place them in the mid-range. Considering the errors and the occasional awkward phrasing, I would say a score of 6.0. They show some range but also consistent errors that affect clarity.
# </think>
#
# <CONCLUSION>6.0</CONCLUSION>
# Extracted:
# 6.0
# ******************** Question:
# Evaluate the following answer(s) for IELTS speaking test for the rubric "Lexical Resource".
#
# Items to be evaluated:
# IELTS speaking test part: Part 1
# Topic: Cultural Awareness
# Questions:
# What does cultural awareness mean to you?
# How do you learn about different cultures?
# Have you ever experienced a culture shock? Can you share that experience?
# Why do you think it is important to understand other cultures?
#
# Answers:
# Cultural awareness means understanding the values, customs, and social behaviors of different groups of people. It helps us interact respectfully with others from diverse backgrounds.
# I learn about different cultures mainly through travel experiences, reading literature about other countries, watching cultural documentaries, and meeting people from various ethnicities.
# Yes, I experienced culture shock when I first moved abroad. The language barrier and unfamiliar social etiquette made me feel quite uncomfortable initially but over time I adapted well.
# It’s important to understand other cultures because it fosters mutual respect, reduces misunderstandings, and enriches our worldview.
#
# Topic: Urban Development
# Questions:
# What are some positive aspects of urban development?
# How do you think urban areas can be improved?
# What challenges do cities face regarding development?
# Do you prefer living in a city or a rural area? Why?
#
# Answers:
# Urban development has positive aspects like creating job opportunities, improving infrastructure such as roads and public transport, and enhancing living standards for residents.
# Urban areas can be improved by focusing on sustainable development practices including green spaces, efficient waste management, and affordable housing projects.
# Cities face challenges such as overcrowding, pollution, traffic congestion, and social disparities which require careful planning to address effectively.
# I prefer living in a city due to the availability of amenities like schools, hospitals, cultural activities, and better career prospects.
#
# CTTR: 7.632
# Answer:
# 7
# Response:
# <think>
# Okay, let's start by looking at the user's query. They want me to evaluate IELTS speaking answers based on the "Lexical Resource" rubric for Part 1. The topics are Cultural Awareness and Urban Development, with answers provided for each. The user also mentions a CTTR score of 7.632, which I assume is their current score, and they want to know how to improve their lexical resource score.
#
# First, I need to recall the IELTS Lexical Resource criteria. It assesses the range of vocabulary used, accuracy, and appropriateness. So, I should check if the answers use a sufficient variety of vocabulary, if the words are used correctly in context, and if they are appropriate for the topic.
#
# Looking at the Cultural Awareness answers, the first answer defines cultural awareness with terms like "values," "customs," "social behaviors," and "interact respectfully." That's a good range. The second answer mentions "travel experiences," "literature," "cultural documentaries," and "ethnicities." These are specific and varied. The third answer talks about "culture shock," "language barrier," "unfamiliar social etiquette," and "adapt." The last answer uses "mutual respect," "misunderstandings," "enriches our worldview." All these terms are appropriate and show a good range.
#
# ...
# </COMMENT>
#
# <CONCLUSION>6.5</CONCLUSION>
# Extracted:
# 6.5
# ******************** Question:
# Evaluate the following answer(s) for IELTS speaking test for the rubric "Grammatical Range and Accuracy".Items to be evaluated:IELTS speaking test part: Part 3Topic: Community EngagementQuestions:What role do community organizations play in society?How can individuals contribute to their local communities?Do you think volunteering is important? Why or why not?What are some challenges communities face when trying to engage their members?Answers:Community organizations is important for society because they help people and make place better.People can contribute by helping in events or cleaning places in community.Yes, volunteering is important because it help people and also make person happy.Challenges is some people no want join or no have time for community things.
# Answer:
# 2
# Response:
# <think>
# Okay, let's evaluate the student's answer for the IELTS Speaking test rubric "Grammatical Range and Accuracy." The student answered questions about community engagement. I'll check each answer for grammatical errors, sentence structure, and range of vocabulary.
#
# First question: "Community organizations is important for society because they help people and make place better." The error here is "is" instead of "are" because "organizations" is plural. "Make place better" should be "make places better" or "make the place better."
#
# Second answer: "People can contribute by helping in events or cleaning places in community." The phrase "in community" is incorrect; it should be "in their community." Also, "cleaning places" might be better as "cleaning up places" or "participating in clean-up events."
#
# Third answer: "Yes, volunteering is important because it help people and also make person happy." The verbs "help" and "make" are in the base form instead of past tense. Also, "person" should be "people" or "a person."
#
# Fourth answer: "Challenges is some people no want join or no have time for community things." "Challenges is" should be "Challenges are." "No want join" should be "don't want to join." "No have time" should be "don't have time." Also, "community things" is a bit vague; "community activities" or "community events" might be better.
#
# Overall, there are several grammatical errors affecting accuracy. The range of grammar is limited, with simple sentence structures and some incorrect verb forms. The student uses basic vocabulary and doesn't vary sentence structures much. The errors impact clarity and coherence. The score would likely be a 4.5 because the student attempts to answer but has frequent errors that hinder understanding.
# </think>
#
# <CONCLUSION>4.5</CONCLUSION>
# Extracted:
# 4.5
# ******************** Question:
# Evaluate the following answer(s) for IELTS speaking test for the rubric "Grammatical Range and Accuracy".Items to be evaluated:IELTS speaking test part: Part 1Topic: Personal AchievementsQuestions:What is an achievement you are proud of?How did you feel when you accomplished this goal?Are there any goals you are currently working towards?How do personal achievements affect your self-confidence?Answers:One achievement that I am proud of is graduating from university. It took a lot of effort and time.When I accomplished this goal, I felt very happy and relieved because it was challenging.Currently, I am working towards improving my English speaking skills for better job opportunities.Personal achievements definitely boost my self-confidence and encourage me to set higher goals.Topic: Environmental AwarenessQuestions:What are some ways people can be more environmentally friendly?Do you think individuals can make a difference in protecting the environment?Have you participated in any environmental initiatives or campaigns?What changes would you like to see in your community regarding environmental issues?Answers:People can be more environmentally friendly by recycling waste, reducing plastic use, and saving energy.Yes, individuals can make a difference if many people take small actions together to protect the environment.I have participated in a local tree planting campaign last year which was a good experience.In my community, I would like to see better waste management systems and more awareness about pollution.
# Answer:
# 5
# Response:
# <think>
# Okay, let's start by evaluating the student's answers for the "Grammatical Range and Accuracy" criterion in the IELTS Speaking test. This criterion assesses the variety of grammar structures used and the accuracy of their application.
#
# First, I'll look at the Part 1 answers on Personal Achievements. The student mentions graduating from university, which is straightforward. They use simple past tense ("It took a lot of effort and time") and present perfect ("I am working towards"). Then they talk about feeling happy and relieved, using past tense correctly. The part about improving English uses present continuous, which is appropriate. The last answer about personal achievements and self-confidence is concise but uses simple present tense. There's a mix of tenses here, and they seem to handle them correctly without obvious errors.
#
# Moving to the Environmental Awareness topic. The student talks about ways to be environmentally friendly, using infinitives ("recycling waste, reducing plastic use, and saving energy") which is correct. The response to whether individuals can make a difference uses a conditional structure ("if many people take small actions together") which is properly constructed. The third answer mentions participation in a campaign last year, using past tense appropriately. The last answer about changes in the community uses present tense for desired changes, which is correct. There are some basic sentence structures, but they are used accurately.
#
# Looking for errors: I don't see any major grammatical mistakes. The student uses a range of tenses and structures appropriately. They might have used more complex structures if they had elaborated more, but what they've used is correct. The vocabulary is also appropriate, though the complexity is moderate. The answers are clear and the grammar is accurate, though there's a limited variety in terms of complex structures. The student might have used more varied sentence structures to score higher, but what's present is correct and functional. So, the score would be in the high 6 or low 7 range for grammatical range and accuracy.
# </think>
#
# <CONCLUSION>7</CONCLUSION>
# Extracted:
# 7
# ******************** Question:
# Evaluate the following answer(s) for IELTS speaking test for the rubric "Lexical Resource".
#
# Items to be evaluated:
# IELTS speaking test part: Part 2
# Topic: -
# Question: Describe a time when you took a risk. What was the risk and what was the outcome?
#
# Answer:
# One time, I took risk to start my own business. It was difficult because I have little money and no experience. But I try hard and now business is okay.
#
# CTTR: 3.486
# Answer:
# 4
# Response:
# <think>
# Okay, let's start by looking at the student's answer for the "Lexical Resource" rubric in the IELTS Speaking Part 2. The topic was describing a time when they took a risk, specifically starting their own business. The answer is: "One time, I took risk to start my own business. It was difficult because I have little money and no experience. But I try hard and now business is okay."
#
# First, I need to check the range of vocabulary used. The student mentions "risk," "business," "money," "experience," "try hard," and "okay." The vocabulary is very basic and repetitive. Words like "risk" are used without articles ("a risk"), which is a grammatical error but also affects lexical resource as the student doesn't vary their vocabulary. The phrase "try hard" is a common collocation, but it's not particularly sophisticated. The use of "okay" instead of more precise terms like "successful" or "profitable" shows limited lexical variety.
#
# Looking at the complexity of vocabulary, there's a lack of advanced or varied words. The student could have used terms like "venture," "financial constraints," "inexperienced," "perseverance," or "succeeded." Instead, they stick to simple words. Also, the use of "have" instead of "had" for past tense and "try hard" instead of "tried hard" indicates a lack of accurate lexical choice and tense consistency.
#
# The student doesn't use any specialized vocabulary related to business or entrepreneurship, which could have demonstrated a higher level of lexical resource. The sentence structure is also simple, with minimal use of connectives or complex structures that might incorporate more sophisticated vocabulary.
#
# In terms of collocations, "take a risk" is correct, but the rest of the sentence lacks natural collocations. "I have little money" is grammatically incorrect in the past tense and also uses "have" instead of "had." The phrase "now business is okay" is informal and doesn't convey the nuance of the outcome effectively.
#
# The lexical resource score would be low because of the limited vocabulary, repetition, and lack of appropriate collocations. The student didn't use a wide range of vocabulary to discuss the topic effectively, and there were several lexical errors that affected clarity and precision.
# </think>
#
# <CONCLUSION>6.0</CONCLUSION>
# Extracted:
# 6.0
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/tmp/ipykernel_26156/3917720072.py", line 35, in <module>
#     trainer.train()
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/transformers/trainer.py", line 2245, in train
#     return inner_training_loop(
#   File "<string>", line 314, in _fast_inner_training_loop
#   File "<string>", line 25, in _unsloth_training_step
#   File "/home/ducanh/nvidia-llm-pipeline/unslot/ft_qwen/qrpo/unsloth_compiled_cache/UnslothGRPOTrainer.py", line 972, in _prepare_inputs
#     prompt_completion_ids = unwrapped_model.generate(
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/unsloth/models/rl.py", line 69, in generate_with_clone
#     out = original_generate(*args, **kwargs)
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/peft/peft_model.py", line 1875, in generate
#     outputs = self.base_model.generate(*args, **kwargs)
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/unsloth/models/llama.py", line 1581, in unsloth_fast_generate
#     output = self._old_generate(*args, **kwargs)
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/transformers/generation/utils.py", line 2465, in generate
#     result = self._sample(
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/transformers/generation/utils.py", line 3434, in _sample
#     outputs = model_forward(**model_inputs, return_dict=True)
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1750, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/unsloth/models/llama.py", line 1033, in _CausalLM_fast_forward
#     outputs = fast_forward_inference(
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/unsloth/models/llama.py", line 966, in LlamaModel_fast_forward_inference_custom
#     X, present_key_value = attention_fast_forward_inference(
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/unsloth/models/qwen3.py", line 308, in Qwen3Attention_fast_forward_inference
#     RH_Q[:,:,:,:h].neg_() # torch.neg(RH_Q[:,:,:,:h], out = RH_Q[:,:,:,:h])
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1457, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1348, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1195, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1110, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/IPython/core/ultratb.py", line 992, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/IPython/core/ultratb.py", line 804, in lines
#     return self._sd.lines
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/stack_data/core.py", line 645, in included_pieces
#     scope_pieces = self.scope_pieces
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/stack_data/core.py", line 585, in scope_pieces
#     for piece in self.source.pieces
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/stack_data/core.py", line 90, in pieces
#     return list(self._clean_pieces())
#   File "/home/ducanh/data/miniconda3/envs/unsloth/lib/python3.10/site-packages/stack_data/core.py", line 114, in _clean_pieces
#     raise AssertionError("Pieces mismatches: %s" % mismatches)
# AssertionError: Pieces mismatches: [{851, 852}]

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model via Unsloth native inference! According to the `Qwen-3` team, the recommended settings for reasoning inference are `temperature = 0.6, top_p = 0.95, top_k = 20`
#
# For normal chat based inference, `temperature = 0.7, top_p = 0.8, top_k = 20`

# %%
messages = [
    {"role" : "user", "content" : "Solve (x + 2)^2 = 0."}
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize = False,
    add_generation_prompt = True, # Must add for generation
    enable_thinking = False, # Disable thinking
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer(text, return_tensors = "pt").to("cuda"),
    max_new_tokens = 256, # Increase for longer outputs!
    temperature = 0.7, top_p = 0.8, top_k = 20, # For non thinking
    streamer = TextStreamer(tokenizer, skip_prompt = True),
)

# %%
messages = [
    {"role" : "user", "content" : """
Evaluate the following answer(s) for IELTS speaking test for the rubric "Grammatical Range and Accuracy". Items to be evaluated: IELTS speaking test part: Part 3 Topic: Cultural Identity Questions: What things make a person's cultural identity? You mention some of the factors that can determine the cultural identity of a person. Which of these do you think the most important? Why does some culture not survive? Some people say some cultures will die because of globalization. What do you say? Topic: Citizenship Questions: What things make a good citizen these days? Is being a good citizen the same in every country? Why? Why might some people wish to be citizens of other country? ``` Answers for evaluating Grammatical Range and Accuracy: I suppose the country where he or she is from because it's different culture he was born and raised in different cultures different literature different music different language and different traditions that's why I suppose all the people are not the same because they have different point of views at different problems and different issues because they are born and raised in different conditions. Traditions, traditions, language, maybe in any languages you even cannot find some words which are, those are in your own language. That's why they, the people who speak, speak those language, that language, they can even don't know about the problems and words like that. Because they weren't adapted to the conditions which were changed. I suppose, I don't know, maybe they just simply assimilated into other cultures and it was easier to assimilate than to support their own culture. I suppose, yes. I can give the example that my grandmother, she's Komi, but she and her husband, who is also Komi, didn't teach their children their language and their traditions because they don't, they didn't think it's useful. Good citizen, I don't know, you can, uh, you have to, uh, just, um, I forgot the word, uh, you have to, um, not to bother, I don't remember, not to bother other people, uh, you have to, um, behave yourself like you, uh, want other people behave yourself with you, that's the only rule, I suppose, not to, um, make any harm or... Is being a good citizen the same in every country? I suppose yes. Because the only... to respect laws, to respect other people, respect... I remember the word... is the only rule to live... I don't know... to be the good citizen, to be the good man or woman or... Maybe they like, they like other countries' rules more or other countries' conditions, I don't know, people in other countries. Because many people in some countries don't realize that they should behave themselves well     """}
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize = False,
    add_generation_prompt = True, # Must add for generation
    enable_thinking = True, # Disable thinking
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer(text, return_tensors = "pt").to("cuda"),
    max_new_tokens = 1024, # Increase for longer outputs!
    temperature = 0.6, top_p = 0.95, top_k = 20, # For thinking
    streamer = TextStreamer(tokenizer, skip_prompt = True),
)

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("/home/ducanh/nvidia-llm-pipeline/unslot/saves/lora_Qwen14b_qrpo")  # Local saving
tokenizer.save_pretrained("/home/ducanh/nvidia-llm-pipeline/unslot/saves/lora_Qwen14b_qrpo")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# ('/home/ducanh/nvidia-llm-pipeline/unslot/saves/lora_Qwen14b_qrpo/tokenizer_config.json',
#  '/home/ducanh/nvidia-llm-pipeline/unslot/saves/lora_Qwen14b_qrpo/special_tokens_map.json',
#  '/home/ducanh/nvidia-llm-pipeline/unslot/saves/lora_Qwen14b_qrpo/vocab.json',
#  '/home/ducanh/nvidia-llm-pipeline/unslot/saves/lora_Qwen14b_qrpo/merges.txt',
#  '/home/ducanh/nvidia-llm-pipeline/unslot/saves/lora_Qwen14b_qrpo/added_tokens.json',
#  '/home/ducanh/nvidia-llm-pipeline/unslot/saves/lora_Qwen14b_qrpo/tokenizer.json')

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = 2048,
        load_in_4bit = True,
    )

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.
